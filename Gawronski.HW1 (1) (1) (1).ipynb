# %%
pip install nbconvert[webpdf]
jupyter nbconvert --to webpdf --allow-chromium-download your-notebook-file.ipynb
jupyter nbconvert --to webpdf --no-input your-notebook-file.ipynb
# Out:
#   Cell In[5], line 1
#     pip install nbconvert[webpdf]
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

df1 = pd.read_csv("C:\\Users\\eoing\\Downloads\\players (3).csv")
df2 = pd.read_csv("C:\\Users\\eoing\\Downloads\\salaries_1985to2018.csv")

# %%
import pandas as pd

df1 = pd.read_csv("C:\\Users\\eoing\\Downloads\\players (3).csv")
df2 = pd.read_csv("C:\\Users\\eoing\\Downloads\\salaries_1985to2018.csv")

# Merge the datasets
merged_df = pd.merge(df1, df2, on='_id', how='inner')
merged_df
# Out:
#              _id          birthDate                      birthPlace  \
# 0      abdelal01      June 24, 1968                    Cairo, Egypt
# 1      abdelal01      June 24, 1968                    Cairo, Egypt
# 2      abdelal01      June 24, 1968                    Cairo, Egypt
# 3      abdelal01      June 24, 1968                    Cairo, Egypt
# 4      abdelal01      June 24, 1968                    Cairo, Egypt
# ...          ...                ...                             ...
# 14158  zipsepa01  February 18, 1994             Heidelberg, Germany
# 14159  zipsepa01  February 18, 1994             Heidelberg, Germany
# 14160  zizican01    January 4, 1997                  Split, Croatia
# 14161  zubaciv01     March 18, 1997  Mostar, Bosnia and Herzegovina
# 14162  zubaciv01     March 18, 1997  Mostar, Bosnia and Herzegovina
#
#        career_AST career_FG% career_FG3% career_FT%  career_G career_PER  \
# 0             0.3       50.2         0.0       70.1       256       13.0
# ...

# %%
merged_df.dtypes
# Out:
# _id              object
# birthDate        object
# birthPlace       object
# career_AST      float64
# career_FG%       object
# career_FG3%      object
# career_FT%       object
# career_G          int64
# career_PER       object
# career_PTS      float64
# career_TRB       object
# career_WS        object
# career_eFG%      object
# college          object
# draft_pick       object
# draft_round      object
# draft_team       object
# draft_year       object
# height           object
# highSchool       object
# name             object
# position         object
# shoots           object
# weight           object
# league           object
# salary            int64
# season           object
# season_end        int64
# season_start      int64
# team             object
# dtype: object

# %% [markdown]
# I chose this criteria becasue its important to look a NBA statistics, name, id, and other feautures when analyzing the dataset. I was hoping to look at statistics and salaries to see relationships. The main goal would be to create a system that determines players salaries based off factors.

# %% [markdown]
# The important features in this dataset are career_pts, career_FG%, player name, id, salary, and team. These are a few categories that will bhe important in determing my system and appication.

# %%
# Assuming df is your loaded dataset
data_dictionary = pd.DataFrame({
    'Column Name': ['career_PTS', 'salary', 'career_FG%', 'name',],
    'Data Type': ['float64', 'int64', 'object' 'object'],
    'Description': [
        'Career Points',
        'Salary of Players',
        'FG percentage',
        'Name of player',
    ]
})

print(data_dictionary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Assuming df is your loaded dataset
# ----> 2 data_dictionary = pd.DataFrame({
#       3     'Column Name': ['career_PTS', 'salary', 'career_FG%', 'name',],
#       4     'Data Type': ['float64', 'int64', 'object' 'object'],
#       5     'Description': [
#       6         'Career Points',
#       7         'Salary of Players',
#       8         'FG percentage',
#       9         'Name of player',
#      10     ]
#      11 })
#      13 print(data_dictionary)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
# ...
